# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
original_df = pd.read_hdf("../dataset/credit_card_fraud.h5",key="fraud_dataset")
synthetic_df = pd.read_hdf("../dataset/synthetic_dataset.h5",key="fraud_dataset")
quantile_synthetic_df = pd.read_hdf("../dataset/synthetic_dataset_quantile.h5",key="fraud_dataset")

# %%
synthetic_df.columns = original_df.columns
synthetic_df.head()
# Out:
#    TransactionType   Channel  CustomerAge  CustomerOccupation  \
# 0         0.785812  0.926517    44.744091            1.459439
# 1         0.771649  0.975486    44.636940            1.569917
# 2         0.855860  0.832092    44.318195            1.594601
# 3         0.777393  0.918314    43.881752            1.511305
# 4         0.772774  0.964213    44.997959            1.435109
#
#    TransactionDuration  LoginAttempts  AccountBalance  \
# 0           116.778267       1.104972     5276.654297
# 1           118.121971       1.093149     5059.114258
# 2           130.642258       1.076298     4831.396973
# 3           114.746231       1.083755     4999.174316
# 4           115.632927       1.104426     5411.863770
#
#    PreviousTransactionDate  TransactionDate_hour  TransactionWeekNumber  \
# 0                 2.811462             16.692360              26.616535
# 1                 2.953065             16.655685              27.132727
# 2                 2.680327             16.647310              30.205626
# 3                 2.804734             16.701735              27.217882
# 4                 2.888220             16.627714              26.602537
#
#    DaysSinceLastPurchase
# 0             486.678619
# 1             485.746429
# 2             477.464691
# 3             489.396576
# 4             489.060333

# %%
n_cols = len(original_df.columns)
fig, axs =  plt.subplots(n_cols,2, figsize=(15,30))
for index, var in enumerate(original_df.columns):
    original_df[var].hist(ax=axs[index,0])
    synthetic_df[var].hist(ax=axs[index,1])
    axs[index,0].set_title(var)
